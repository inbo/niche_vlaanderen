# %%
from niche_vlaanderen import Niche
from niche_vlaanderen.bwk_overlay import NicheOverlay


# logger.setLevel(logging.DEBUG)

# %%
nv = Niche()
nv.run_config_file("../tests/data/bwk/niche_brasschaat/simple.yaml")

no_full = NicheOverlay(niche=nv, map="../tests/data/bwk/BWK_edit_20190207.shp")
no_full.overlay()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 14/14 [01:02<00:00,  4.50s/it]
# /home/johan/Nextcloud/_proj/niche/niche_vlaanderen/niche_vlaanderen/bwk_overlay.py:204: RuntimeWarning: invalid value encountered in double_scalars
#   area_pot_perc = area_pot / (area_pot + area_nonpot)
# /home/johan/Nextcloud/_proj/niche/niche_vlaanderen/niche_vlaanderen/bwk_overlay.py:208: RuntimeWarning: invalid value encountered in double_scalars
#   [100 * area_pot / area_effective, 100]
# /home/johan/Nextcloud/_proj/niche/niche_vlaanderen/niche_vlaanderen/bwk_overlay.py:208: RuntimeWarning: divide by zero encountered in double_scalars
#   [100 * area_pot / area_effective, 100]

# %%
no_full.store(path="./tmp/brasschaat")

# %%
no_full.summary
# Out:
#             area_effective      nonpot  nonpot_opt         pot  polygon_count  \
# vegetation
# 1.0               0.617140    1.433977    0.617140    0.000000            5.0
# 2.0               4.898596    6.733458    3.340364    1.558671            8.0
# 3.0               6.566876    6.920499    6.566876    0.000000            7.0
# 4.0               0.534600    0.685815    0.534600    0.000000            1.0
# 6.0             302.359795  329.939451  180.108721  203.313029          172.0
# 12.0              0.787588    0.000000    0.000000    0.872856            1.0
# 14.0              1.176099    1.309284    1.176099    0.000000            3.0
# 18.0              1.109690    1.558671    0.414247    1.059896            3.0
# 20.0              5.808453   29.053625    5.808453    0.000000            2.0
# 21.0              3.277699    2.930301    2.965964    0.311734            1.0
# 22.0             51.028533   65.339483   46.619153    9.601413          115.0
# ...

# %%
no_full.area_pot_perc
# Out:
# vegetation  1.0   2.0   3.0   4.0   6.0   12.0  14.0  18.0  20.0  21.0  22.0  \
# shape_id
# 0            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...          ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 3463         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3464         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3465         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3466         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3467         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# vegetation  25.0  27.0  28.0
# ...
